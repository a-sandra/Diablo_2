# %%
import sys, os
sys.path.append(r"C:\Users\s.aumon\OneDrive - Advanced Oncotherapy plc\Python_Packages\Diablo_2")

#sys.path
from beam import beam

# %%
bm = beam.Beam()
# Out:
# beam created without any input beam distribution. Use read_distribution(filename)

# %%
#os.getcwd()

# %%
input_distribution = "../distributions/CCL_Output_99.0.dat"
bm_distribution = beam.Beam(input_distribution)
# Out:
# Hello
# je suis la

# %%
bm_distribution

# %%
bm_distribution.distribution
# Out:
#           X(mm)  XP(mrad)     Y(mm)  YP(mrad)      Z(mm)     W(MeV)
# 0     -0.013987 -0.507061  0.591221  0.570521 -26.412570   98.34275
# 1     -0.076495  0.604121  0.374664  0.449614  62.971430  100.60880
# 2      0.120022 -1.843409  0.271826  0.270927 -71.107060   97.24772
# 3     -0.446440  0.198818  0.212682  0.279562  31.495370   99.79799
# 4      0.173062  0.020461 -0.967764 -0.511022  71.826820  100.83660
# ...         ...       ...       ...       ...        ...        ...
# 19804  0.233932 -0.772359 -0.232541 -0.531437 -26.013140   98.35135
# 19805  0.012570 -0.079047  1.309734  1.669478  -0.864395   98.97989
# 19806  0.226105 -0.651668 -0.029067  0.072350 -10.474390   98.73808
# 19807 -0.421019  0.648993  0.369429  0.527324 -48.405660   97.80023
# 19808 -0.387031  0.736840  0.102076  0.197742 -21.058730   98.47498
#
# [19809 rows x 6 columns]

# %%
bm_distribution.emittance_calculation()
bm_distribution.e_x, bm_distribution.e_y
# Out:
# (0.06228325100836928, 0.08238682413940983)

# %%
bm_distribution.phase_space_hist()

# %%
x = bm_distribution.x
y = bm_distribution.y
bm_distribution.single_2D_phase_plot(1, x, y, -1, 1, -3, 3, "Xmm", "Ymm")
